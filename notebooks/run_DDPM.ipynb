# %%
 # !pip install icecream category_encoders tomli tomli_w zero sdmetrics synthcity prdc

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd 'drive/MyDrive/Thesis (masters)'
# Out:
# /content/drive/MyDrive/Thesis (masters)

# %%
# !python download_dataset.py
# !python process_dataset.py

# %%
# !python main.py --dataname adult --method tabddpm --mode train
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# Step 97502/100000 MLoss: 0.8424 GLoss: 0.2615 Sum: 1.1039
# Step 97503/100000 MLoss: 0.8151 GLoss: 0.2784 Sum: 1.0935000000000001
# Step 97500/100000 MLoss: 0.8228 GLoss: 0.2677 Sum: 1.0905
# Step 97501/100000 MLoss: 0.8467 GLoss: 0.2678 Sum: 1.1145
# Step 97502/100000 MLoss: 0.8424 GLoss: 0.2615 Sum: 1.1039
# Step 97503/100000 MLoss: 0.8151 GLoss: 0.2784 Sum: 1.0935000000000001
# Step 97504/100000 MLoss: 0.856 GLoss: 0.2754 Sum: 1.1314
# Step 97505/100000 MLoss: 0.8356 GLoss: 0.2742 Sum: 1.1098
# Step 97506/100000 MLoss: 0.8536 GLoss: 0.2731 Sum: 1.1267
# Step 97507/100000 MLoss: 0.792 GLoss: 0.2641 Sum: 1.0561
# Step 97504/100000 MLoss: 0.856 GLoss: 0.2754 Sum: 1.1314
# Step 97505/100000 MLoss: 0.8356 GLoss: 0.2742 Sum: 1.1098
# Step 97506/100000 MLoss: 0.8536 GLoss: 0.2731 Sum: 1.1267
# Step 97507/100000 MLoss: 0.792 GLoss: 0.2641 Sum: 1.0561
# Step 97508/100000 MLoss: 0.8448 GLoss: 0.2693 Sum: 1.1141
# ...

# %%
# !python main.py --dataname adult --method tabddpm --mode sample --save_path samples
# Out:
# START SAMPLING
# No NaNs in numerical features, skipping
# mlp
# ...

# %%
# !python eval/eval_density.py --dataname adult --model tabddpm --path samples
# Out:
# samples
# Generating report ...
#
# (1/2) Evaluating Column Shapes: 100% 15/15 [00:00<00:00, 96.13it/s]
# Column Shapes Score: 98.73%
#
# (2/2) Evaluating Column Pair Trends: 100% 105/105 [00:01<00:00, 61.69it/s]
# Column Pair Trends Score: 97.44%
#
# Overall Score (Average): 98.09%
#
# Generating report ...
#
# (1/2) Evaluating Data Validity: 100% 15/15 [00:00<00:00, 249.91it/s]
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: 100% 1/1 [00:00<00:00, 663.13it/s]
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%

# %%
# !python eval/eval_quality.py --dataname adult --model tabddpm --path samples
# Out:
# [KeOps] Compiling cuda jit compiler engine ... OK
# [pyKeOps] Compiling nvrtc binder for python ... OK
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1739565974.296397   43451 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1739565974.364643   43451 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# samples
# =========== All Features ===========
# Data shape:  (32561, 110)
# alpha precision: 0.939420, beta recall: 0.505937

# %%
# !python eval/eval_mle.py --dataname adult --model tabddpm --path samples
# Out:
# 100% 36/36 [00:16<00:00,  2.16it/s]
# Saving scores to  eval/mle/adult/tabddpm.json

# %%
import json
from pprint import pprint

with open('./eval/mle/adult/tabddpm.json', 'r') as file:
    data = json.load(file)
pprint(data)
# Out:
# {'best_acc_scores': {'XGBClassifier': {'accuracy': 0.8575640316933849,
#                                        'binary_f1': 0.6629850312454585,
#                                        'roc_auc': 0.9114951831688065,
#                                        'weighted_f1': 0.7212655371231678}},
#  'best_auroc_scores': {'XGBClassifier': {'accuracy': 0.8575640316933849,
#                                          'binary_f1': 0.6629850312454585,
#                                          'roc_auc': 0.9114951831688065,
#                                          'weighted_f1': 0.7212655371231678}},
#  'best_avg_scores': {'XGBClassifier': {'accuracy': 0.8575640316933849,
#                                        'binary_f1': 0.6629850312454585,
#                                        'roc_auc': 0.9114951831688065,
#                                        'weighted_f1': 0.7212655371231678}},
#  'best_f1_scores': {'XGBClassifier': {'accuracy': 0.8575640316933849,
# ...

# %%
# !python eval/eval_dcr.py --dataname adult --model tabddpm --path samples
# Out:
# DCR Score, a value closer to 0.5 is better
# adult-tabddpm, DCR Score = 0.6773747735020423
# DCR Score, a value closer to 0.5 is better
# adult-tabddpm, DCR Score = 0.6794324498633334
